# %%
# !echo $LD_LIBRARY_PATH
# Out:
# /opt/ros/noetic/lib::/usr/local/cuda-12.4/lib64:/home/liwenbo/CoppeliaSim

# %%
import openai
from arguments import get_config
from interfaces import setup_LMP
from visualizers import ValueMapVisualizer
from envs.rlbench_env import VoxPoserRLBench
from utils import set_lmp_objects
import numpy as np
from rlbench import tasks

openai.api_key = "sk-cgpibTHnxWRPOUxdb05uaf9wPc687e0mc4EJIzpNjT3G2q5F"
openai.api_base= "https://api.chatanywhere.tech/v1"
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Setup

# %%
config = get_config('rlbench')
# uncomment this if you'd like to change the language model (e.g., for faster speed or lower cost)
# for lmp_name, cfg in config['lmp_config']['lmps'].items():
#     cfg['model'] = 'gpt-3.5-turbo'

# initialize env and voxposer ui
visualizer = ValueMapVisualizer(config['visualizer'])
env = VoxPoserRLBench(visualizer=visualizer)
lmps, lmp_env = setup_LMP(env, config, debug=False)
voxposer_ui = lmps['plan_ui']
# Out:
# ##################################################
# ## voxel resolution: [0.0105 0.0131 0.01  ]
# ##################################################

# %% [markdown]
# ## Playground
#
# By default we use one of the instructions that come with each task. However, you may treat each task as simply a scene initialization from RLBench, and feel free to try any task you can come up with for the scene.
#
# Note:
# - Whether an instruction can be executed or not depends on 1) whether relevant objects are available, and 2) capabilities of the overall algorithm.
# - Each execution may produce one or more visualizations. You may view them in "./visualizations/" folder.
# - The prompts are adapted with minimal change from the real-world environment in the VoxPoser paper. If a task failure is due to incorrect code generated by the LLM, feel free to modify the relevant prompt in "./prompts/" folder.
# - You may view the reward by printing "env.latest_reward". These are computed by RLBench for each task.
# - To inspect in viewer without performing any action, you may call "env.rlbench_env._scene.step()" in a loop.

# %%
# # uncomment this to show all available tasks in rlbench
# # NOTE: in order to run a new task, you need to add the list of objects (and their corresponding env names) to the "task_object_names.json" file. See README for more details.
# print([task for task in dir(tasks) if task[0].isupper() and not '_' in task])

# %%
# below are the tasks that have object names added to the "task_object_names.json" file
# uncomment one to use
# env.load_task(tasks.PutRubbishInBin)
# env.load_task(tasks.LampOff)
# env.load_task(tasks.OpenWineBottle)
env.load_task(tasks.PushButton)
# env.load_task(tasks.TakeOffWeighingScales)
# env.load_task(tasks.MeatOffGrill)
# env.load_task(tasks.SlideBlockToTarget)
# env.load_task(tasks.TakeLidOffSaucepan)
# env.load_task(tasks.TakeUmbrellaOutOfUmbrellaStand)

descriptions, obs = env.reset()
set_lmp_objects(lmps, env.get_object_names())  # set the object names to be used by voxposer

# %%
instruction = np.random.choice(descriptions)
voxposer_ui(instruction)
# Out:
# *** OpenAI API call took 2.55s ***
# ########################################
# ## "planner" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: put rubbish in bin.
# composer("grasp the rubbish")
# composer("back to default pose")
# composer("move to 10cm on top of the bin")
# composer("open gripper")
# composer("back to default pose")
# # done
#
#
# *** OpenAI API call took 2.40s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: grasp the rubbish.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point at the center of the rubbish')
# gripper_map = get_gripper_map('open everywhere except 1cm around the rubbish')
# execute(movable, affordance_map=affordance_map, gripper_map=gripper_map)
#
#
# *** OpenAI API call took 1.10s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 2.22s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point at the center of the rubbish.
# affordance_map = get_empty_affordance_map()
# rubbish = parse_query_obj('rubbish')
# x, y, z = rubbish.position
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 3.19s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere except 1cm around the rubbish.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# # close when 1cm around the rubbish
# rubbish = parse_query_obj('rubbish')
# set_voxel_by_radius(gripper_map, rubbish.position, radius_cm=1, value=0)
# ret_val = gripper_map
#
#
# *** OpenAI API call took 2.42s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# [planners.py | 14:44:27.149] start
# [planners.py | 14:44:27.223] start optimizing, start_pos: [52 49 71]
# [planners.py | 14:44:27.244] optimization finished; path length: 36
# [planners.py | 14:44:27.244] after postprocessing, path length: 36
# [planners.py | 14:44:27.244] last waypoint: [44.71880294 22.7622812   1.        ]
# [interfaces.py | 14:44:27] planner time: 0.096s
# [interfaces.py | 14:44:27] overwriting gripper to less common value for the last waypoint
# ** saving visualization to ./visualizations/14:44:27.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/14:44:27.html
# [interfaces.py | 14:44:27] start executing path via controller (38 waypoints)
# [interfaces.py | 14:44:29] completed waypoint 1 (wp: [ 0.271 -0.01   1.469], actual: [ 0.272 -0.01   1.469], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.789)
# [interfaces.py | 14:44:29] completed waypoint 2 (wp: [ 0.251 -0.032  1.449], actual: [ 0.252 -0.032  1.449], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.76)
# [interfaces.py | 14:44:29] completed waypoint 3 (wp: [ 0.235 -0.057  1.429], actual: [ 0.236 -0.056  1.429], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.731)
# [interfaces.py | 14:44:29] completed waypoint 4 (wp: [ 0.222 -0.083  1.409], actual: [ 0.223 -0.083  1.408], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.701)
# [interfaces.py | 14:44:29] completed waypoint 5 (wp: [ 0.212 -0.111  1.388], actual: [ 0.213 -0.11   1.388], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.672)
# [interfaces.py | 14:44:29] completed waypoint 6 (wp: [ 0.205 -0.139  1.368], actual: [ 0.205 -0.138  1.368], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.643)
# [interfaces.py | 14:44:29] completed waypoint 7 (wp: [ 0.2   -0.167  1.348], actual: [ 0.201 -0.167  1.348], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.615)
# [interfaces.py | 14:44:29] completed waypoint 8 (wp: [ 0.198 -0.196  1.328], actual: [ 0.198 -0.195  1.328], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.587)
# [interfaces.py | 14:44:29] completed waypoint 9 (wp: [ 0.197 -0.223  1.308], actual: [ 0.197 -0.223  1.307], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.561)
# [interfaces.py | 14:44:30] completed waypoint 10 (wp: [ 0.197 -0.25   1.287], actual: [ 0.197 -0.249  1.287], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.535)
# [interfaces.py | 14:44:30] completed waypoint 11 (wp: [ 0.199 -0.284  1.257], actual: [ 0.198 -0.283  1.257], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.5)
# [interfaces.py | 14:44:30] completed waypoint 12 (wp: [ 0.2   -0.303  1.237], actual: [ 0.2   -0.302  1.237], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.478)
# [interfaces.py | 14:44:30] completed waypoint 13 (wp: [ 0.202 -0.319  1.217], actual: [ 0.202 -0.318  1.217], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.456)
# [interfaces.py | 14:44:30] completed waypoint 14 (wp: [ 0.202 -0.332  1.196], actual: [ 0.202 -0.331  1.196], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.435)
# [interfaces.py | 14:44:30] completed waypoint 15 (wp: [ 0.202 -0.342  1.176], actual: [ 0.202 -0.341  1.176], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.414)
# [interfaces.py | 14:44:30] completed waypoint 16 (wp: [ 0.203 -0.349  1.156], actual: [ 0.203 -0.349  1.156], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.394)
# [interfaces.py | 14:44:30] completed waypoint 17 (wp: [ 0.203 -0.353  1.136], actual: [ 0.203 -0.353  1.136], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.374)
# [interfaces.py | 14:44:30] completed waypoint 18 (wp: [ 0.203 -0.356  1.116], actual: [ 0.203 -0.356  1.116], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.354)
# [interfaces.py | 14:44:30] completed waypoint 19 (wp: [ 0.203 -0.358  1.095], actual: [ 0.203 -0.357  1.095], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.333)
# [interfaces.py | 14:44:30] completed waypoint 20 (wp: [ 0.202 -0.358  1.075], actual: [ 0.202 -0.358  1.075], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.313)
# [interfaces.py | 14:44:30] completed waypoint 21 (wp: [ 0.201 -0.358  1.055], actual: [ 0.201 -0.358  1.055], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.293)
# [interfaces.py | 14:44:31] completed waypoint 22 (wp: [ 0.2   -0.358  1.035], actual: [ 0.2   -0.358  1.035], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.273)
# [interfaces.py | 14:44:31] completed waypoint 23 (wp: [ 0.199 -0.36   1.015], actual: [ 0.199 -0.359  1.015], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.253)
# [interfaces.py | 14:44:31] completed waypoint 24 (wp: [ 0.198 -0.362  0.994], actual: [ 0.198 -0.362  0.995], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.233)
# [interfaces.py | 14:44:31] completed waypoint 25 (wp: [ 0.197 -0.366  0.974], actual: [ 0.197 -0.366  0.975], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.213)
# [interfaces.py | 14:44:31] completed waypoint 26 (wp: [ 0.195 -0.37   0.954], actual: [ 0.195 -0.37   0.954], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.192)
# [interfaces.py | 14:44:31] completed waypoint 27 (wp: [ 0.194 -0.372  0.944], actual: [ 0.194 -0.372  0.944], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.183)
# [interfaces.py | 14:44:31] completed waypoint 28 (wp: [ 0.193 -0.375  0.924], actual: [ 0.193 -0.375  0.924], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.163)
# [interfaces.py | 14:44:31] completed waypoint 29 (wp: [ 0.191 -0.378  0.904], actual: [ 0.191 -0.378  0.903], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.143)
# [interfaces.py | 14:44:31] completed waypoint 30 (wp: [ 0.191 -0.38   0.883], actual: [ 0.19  -0.379  0.883], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.124)
# [interfaces.py | 14:44:31] completed waypoint 31 (wp: [ 0.19  -0.38   0.863], actual: [ 0.19  -0.38   0.863], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.105)
# [interfaces.py | 14:44:31] completed waypoint 32 (wp: [ 0.19  -0.379  0.843], actual: [ 0.19  -0.379  0.843], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.085)
# [interfaces.py | 14:44:31] completed waypoint 33 (wp: [ 0.191 -0.376  0.823], actual: [ 0.191 -0.376  0.823], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.066)
# [interfaces.py | 14:44:32] completed waypoint 34 (wp: [ 0.193 -0.371  0.803], actual: [ 0.193 -0.371  0.802], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.044)
# [interfaces.py | 14:44:32] completed waypoint 35 (wp: [ 0.196 -0.364  0.782], actual: [ 0.195 -0.364  0.783], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.023)
# [interfaces.py | 14:44:32] completed waypoint 36 (wp: [ 0.199 -0.354  0.762], actual: [ 0.199 -0.354  0.762], target: [ 0.199 -0.354  0.762], start: [ 0.271 -0.01   1.469], dist2target: 0.0)
# [interfaces.py | 14:44:32] reached last waypoint; curr_xyz=[ 0.19893846 -0.35382104  0.76198679], target=[ 0.19929036 -0.35380214  0.7621009 ] (distance: 0.000))
# [interfaces.py | 14:44:32] reached target; terminating
# [interfaces.py | 14:44:32] finished executing path via controller
# *** OpenAI API call took 0.90s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()
#
#
# *** OpenAI API call took 2.26s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: move to 10cm on top of the bin.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point 10cm above the bin')
# execute(movable, affordance_map=affordance_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 4.15s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point 10cm above the bin.
# affordance_map = get_empty_affordance_map()
# bin = parse_query_obj('bin')
# (min_x, min_y, min_z), (max_x, max_y, max_z) = bin.aabb
# center_x, center_y, center_z = bin.position
# # 10cm above so we add to z-axis
# x = center_x
# y = center_y
# z = max_z + cm2index(10, 'z')
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 1.14s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: bin.
# bin = detect('bin')
# ret_val = bin
#
#
# [planners.py | 14:44:41.664] start
# [planners.py | 14:44:41.733] start optimizing, start_pos: [52 49 71]
# [planners.py | 14:44:41.745] optimization finished; path length: 22
# [planners.py | 14:44:41.745] after postprocessing, path length: 22
# [planners.py | 14:44:41.745] last waypoint: [55.         63.45849802 29.        ]
# [interfaces.py | 14:44:41] planner time: 0.083s
# ** saving visualization to ./visualizations/14:44:41.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/14:44:41.html
# [interfaces.py | 14:44:41] start executing path via controller (24 waypoints)
# [interfaces.py | 14:44:42] completed waypoint 1 (wp: [ 0.287 -0.019  1.469], actual: [ 0.286 -0.019  1.469], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.471)
# [interfaces.py | 14:44:42] completed waypoint 2 (wp: [0.294 0.021 1.449], actual: [0.294 0.02  1.449], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.437)
# [interfaces.py | 14:44:42] completed waypoint 3 (wp: [0.299 0.055 1.429], actual: [0.3   0.055 1.428], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.405)
# [interfaces.py | 14:44:42] completed waypoint 4 (wp: [0.304 0.085 1.409], actual: [0.304 0.084 1.408], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.377)
# [interfaces.py | 14:44:42] completed waypoint 5 (wp: [0.307 0.11  1.388], actual: [0.307 0.108 1.389], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.352)
# [interfaces.py | 14:44:42] completed waypoint 6 (wp: [0.309 0.13  1.368], actual: [0.309 0.129 1.368], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.328)
# [interfaces.py | 14:44:42] completed waypoint 7 (wp: [0.311 0.146 1.348], actual: [0.311 0.146 1.348], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.305)
# [interfaces.py | 14:44:42] completed waypoint 8 (wp: [0.311 0.159 1.328], actual: [0.311 0.159 1.328], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.284)
# [interfaces.py | 14:44:42] completed waypoint 9 (wp: [0.311 0.169 1.308], actual: [0.311 0.169 1.307], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.263)
# [interfaces.py | 14:44:42] completed waypoint 10 (wp: [0.311 0.176 1.287], actual: [0.311 0.175 1.288], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.243)
# [interfaces.py | 14:44:43] completed waypoint 11 (wp: [0.309 0.183 1.257], actual: [0.309 0.183 1.257], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.212)
# [interfaces.py | 14:44:43] completed waypoint 12 (wp: [0.308 0.185 1.237], actual: [0.308 0.185 1.237], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.192)
# [interfaces.py | 14:44:43] completed waypoint 13 (wp: [0.308 0.185 1.227], actual: [0.308 0.185 1.226], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.181)
# [interfaces.py | 14:44:43] completed waypoint 14 (wp: [0.308 0.183 1.207], actual: [0.308 0.183 1.206], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.161)
# [interfaces.py | 14:44:43] completed waypoint 15 (wp: [0.308 0.181 1.186], actual: [0.308 0.181 1.186], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.141)
# [interfaces.py | 14:44:43] completed waypoint 16 (wp: [0.308 0.178 1.166], actual: [0.308 0.178 1.166], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.121)
# [interfaces.py | 14:44:43] completed waypoint 17 (wp: [0.308 0.176 1.146], actual: [0.308 0.176 1.146], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.101)
# [interfaces.py | 14:44:43] completed waypoint 18 (wp: [0.308 0.174 1.126], actual: [0.308 0.174 1.125], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.081)
# [interfaces.py | 14:44:43] completed waypoint 19 (wp: [0.308 0.174 1.106], actual: [0.308 0.174 1.105], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.061)
# [interfaces.py | 14:44:43] completed waypoint 20 (wp: [0.308 0.175 1.085], actual: [0.308 0.175 1.086], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.042)
# [interfaces.py | 14:44:43] completed waypoint 21 (wp: [0.308 0.178 1.065], actual: [0.308 0.178 1.065], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.021)
# [interfaces.py | 14:44:43] skip waypoint 22 because it is moving in opposite direction of the final target
# [interfaces.py | 14:44:43] skip waypoint 23 because it is moving in opposite direction of the final target
# [interfaces.py | 14:44:43] completed waypoint 24 (wp: [0.308 0.185 1.045], actual: [0.308 0.184 1.046], target: [0.308 0.185 1.045], start: [ 0.287 -0.019  1.469], dist2target: 0.001)
# [interfaces.py | 14:44:43] reached target; terminating
# [interfaces.py | 14:44:43] finished executing path via controller
# *** OpenAI API call took 2.05s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: open gripper.
# movable = parse_query_obj('gripper')
# gripper_map = get_gripper_map('open everywhere')
# execute(movable, gripper_map=gripper_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 1.93s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# ret_val = gripper_map
#
#
# [interfaces.py | 14:44:47] finished executing path via controller
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()
